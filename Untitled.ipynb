# %%
import pandas as pd

# %%
import os
os.listdir("football_matches")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 import os
# ----> 2 os.listdir("football_matches")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'football_matches'
